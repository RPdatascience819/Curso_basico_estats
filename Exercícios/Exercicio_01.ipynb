# %%
import pandas as pd

dados = pd.read_csv('dados.csv')
dados.head()
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %%
classes = [dados.Altura.min(), 1.65, 1.75, dados.Altura.max()]
labels = ['1 - Baixa', '2 - Média', '3 - Alta']

frequencia = pd.value_counts(
    pd.cut(
        x = dados.Altura,
        bins = classes,
        labels = labels,
        include_lowest = True
    )
)

percentual = pd.value_counts(
    pd.cut(
        x = dados.Altura,
        bins = classes,
        labels = labels,
        include_lowest = True
    ), normalize = True
) * 100

dist_freq_altura = pd.DataFrame(
    {'Frequência': frequencia, 'Porcentagem (%)': percentual}
)

dist_freq_altura.rename_axis('Estaturas', axis= 'columns', inplace = True)

dist_freq_altura.sort_index(ascending = True, inplace = True)

dist_freq_altura
# Out:
# C:\Users\BI\AppData\Local\Temp\ipykernel_20528\1120227437.py:4: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frequencia = pd.value_counts(
# C:\Users\BI\AppData\Local\Temp\ipykernel_20528\1120227437.py:13: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   percentual = pd.value_counts(
# Estaturas  Frequência  Porcentagem (%)
# Altura
# 1 - Baixa       20529        26.716554
# 2 - Média       36162        47.061426
# 3 - Alta        20149        26.222020

# %%
# Definir os intervalos de classes e os rótulos
classes = [dados.Altura.min(), 1.65, 1.75, dados.Altura.max()]
labels = ['1 - Baixa', '2 - Média', '3 - Alta']

# Realizar o corte uma única vez
altura_classificada = pd.cut(
    x = dados.Altura,
    bins = classes,
    labels = labels,
    include_lowest = True
)

# Calcular a frequência e o percentual
frequencia = altura_classificada.value_counts(sort=False)
percentual = altura_classificada.value_counts(normalize=True, sort=False) * 100

# Criar o DataFrame com os resultados
dist_freq_altura = pd.DataFrame({
    'Frequência': frequencia,
    'Porcentagem (%)': percentual
})

# Ajustar o índice e ordenar
dist_freq_altura.index.name = 'Estaturas'
dist_freq_altura.sort_index(inplace=True)

# Exibir o DataFrame resultante
dist_freq_altura
# Out:
#            Frequência  Porcentagem (%)
# Estaturas
# 1 - Baixa       20529        26.716554
# 2 - Média       36162        47.061426
# 3 - Alta        20149        26.222020

# %%
# Definir os intervalos de classes e os rótulos
classes = [dados.Altura.min(), 1.65, 1.75, dados.Altura.max()]
labels = ['1 - Baixa', '2 - Média', '3 - Alta']

# Classificar os dados em categorias e calcular as frequências e percentuais
altura_classificada = pd.cut(
    x = dados.Altura,
    bins = classes,
    labels = labels,
    include_lowest = True
)

# Criar o DataFrame diretamente a partir das séries de frequências e percentuais
dist_freq_altura = pd.DataFrame({
    'Frequência': altura_classificada.value_counts(sort=False),
    'Porcentagem': altura_classificada.value_counts(normalize=True, sort=False) * 100
})

# Formatar a coluna de porcentagem para exibir com duas casas decimais
dist_freq_altura['Porcentagem'] = dist_freq_altura['Porcentagem'].map("{:.2f}%".format)

# Ajustar o índice
dist_freq_altura.index.name = 'Estaturas'
dist_freq_altura.sort_index(inplace=True)

# Exibir o DataFrame resultante
dist_freq_altura
# Out:
#            Frequência Porcentagem
# Estaturas
# 1 - Baixa       20529      26.72%
# 2 - Média       36162      47.06%
# 3 - Alta        20149      26.22%

# %%
"""

### 1. **Definição das classes e rótulos**

```python
classes = [dados.Altura.min(), 1.65, 1.75, dados.Altura.max()]
labels = ['1 - Baixa', '2 - Média', '3 - Alta']
```

- **`classes`**: Aqui estamos criando os limites de cada intervalo (ou "bin") que usaremos para categorizar as alturas. Utilizamos a função `dados.Altura.min()` para pegar a menor altura do conjunto de dados, `1.65` e `1.75` como limites intermediários, e `dados.Altura.max()` para pegar a maior altura.
  
- **`labels`**: Esses rótulos representam as categorias que queremos dar para cada intervalo. No nosso caso, usamos "Baixa", "Média" e "Alta" para descrever as alturas.

### 2. **Classificação dos dados em categorias**

```python
altura_classificada = pd.cut(
    x = dados.Altura,
    bins = classes,
    labels = labels,
    include_lowest = True
)
```

- **`pd.cut()`**: Esta função do `pandas` é utilizada para segmentar ou "cortar" os dados em categorias com base em intervalos (`bins`). 
    - **`x = dados.Altura`**: Define que estamos cortando os dados da coluna `Altura`.
    - **`bins = classes`**: Utilizamos os intervalos definidos anteriormente.
    - **`labels = labels`**: Associa os rótulos ('1 - Baixa', '2 - Média', '3 - Alta') a cada intervalo.
    - **`include_lowest = True`**: Isso garante que o menor valor do intervalo será incluído na primeira categoria.

Esse comando resulta em uma série (um tipo de estrutura de dados do pandas) onde cada valor da altura é classificado de acordo com as categorias de altura (Baixa, Média, Alta).

### 3. **Criação do DataFrame com frequências e percentuais**

```python
dist_freq_altura = pd.DataFrame({
    'Frequência': altura_classificada.value_counts(sort=False),
    'Porcentagem (%)': altura_classificada.value_counts(normalize=True, sort=False) * 100
})
```

- **`pd.DataFrame()`**: Estamos criando um `DataFrame`, uma tabela no formato de linhas e colunas, diretamente a partir das contagens e percentuais.
  
    - **`altura_classificada.value_counts(sort=False)`**: Conta quantas alturas caem em cada uma das categorias (Baixa, Média, Alta). O parâmetro `sort=False` garante que os resultados sigam a ordem dos rótulos definidos (em vez de reordenar automaticamente).
  
    - **`altura_classificada.value_counts(normalize=True, sort=False) * 100`**: Aqui usamos `normalize=True` para calcular as proporções relativas de cada categoria (frequência relativa) e depois multiplicamos por 100 para obter os percentuais. 

Essa linha cria o `DataFrame` com duas colunas:
- **Frequência**: O número de alturas que caem em cada categoria.
- **Porcentagem (%)**: O percentual correspondente para cada categoria.

### 4. **Formatação da porcentagem**

```python
dist_freq_altura['Porcentagem (%)'] = dist_freq_altura['Porcentagem (%)'].map("{:.2f}".format)
```

- **`map("{:.2f}".format)`**: Este comando formata os valores da coluna de percentuais para ter duas casas decimais, tornando os valores mais claros e padronizados (ex: 33.33% em vez de 33.333333%).

### 5. **Ajustes no índice e ordenação**

```python
dist_freq_altura.index.name = 'Estaturas'
dist_freq_altura.sort_index(inplace=True)
```

- **`index.name = 'Estaturas'`**: Aqui estamos nomeando o índice do `DataFrame` (que representa as categorias Baixa, Média, Alta) como "Estaturas", tornando a tabela mais descritiva.

- **`sort_index(inplace=True)`**: Garante que os dados sejam exibidos na ordem correta das categorias (Baixa, Média, Alta) com base nos rótulos definidos anteriormente.

### 6. **Exibição do resultado**

```python
dist_freq_altura
```

- Simplesmente exibe o `DataFrame` resultante contendo as colunas de frequência e percentual, com as categorias como o índice.

### Exemplo final do DataFrame:

| Estaturas   | Frequência | Porcentagem (%) |
|-------------|------------|-----------------|
| 1 - Baixa   | 50         | 25.00           |
| 2 - Média   | 100        | 50.00           |
| 3 - Alta    | 50         | 25.00           |

- **Frequência**: Quantidade de pessoas em cada categoria.
- **Porcentagem (%)**: Percentual correspondente em relação ao total.

---

### Resumo:
- **Definição de intervalos (`classes`) e rótulos (`labels`)** para categorizar os dados.
- **Uso do `pd.cut()`** para segmentar os dados em categorias.
- **Criação eficiente de um `DataFrame`** combinando frequências absolutas e percentuais relativas, calculadas com `value_counts()`.
- **Formatação de percentuais** para melhorar a apresentação dos dados.
- **Ordenação e nomeação do índice** para garantir clareza e legibilidade.

Essa abordagem simplifica o código, evitando duplicação e garantindo que o resultado seja organizado e legível.

"""
